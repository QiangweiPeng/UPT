# %%
import scanpy as sc
import numpy as np

# %%
adata = sc.read_h5ad("../../data/raw/norman_2019.h5ad")

# %%
np.sum(adata.obs.guide_ZBTB25)
# Out:
# 1700

# %%
adata.obs.guide_ZBTB25

# %%
adata.obs.perturbation_value
# Out:
# index
# AAACCTGAGAAGAAGC-1   NaN
# AAACCTGAGGCATGTG-1   NaN
# AAACCTGAGGCCCTTG-1   NaN
# AAACCTGCACGAAGCA-1   NaN
# AAACCTGCAGACGTAG-1   NaN
#                       ..
# TTTGTCATCAGTACGT-8   NaN
# TTTGTCATCCACTCCA-8   NaN
# TTTGTCATCCCAACGG-8   NaN
# TTTGTCATCCTCCTAG-8   NaN
# TTTGTCATCTGGCGAC-8   NaN
# Name: perturbation_value, Length: 111255, dtype: float64

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 111255 × 19018
# ...
